# %%
# !pip install buildozer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting buildozer
#   Downloading buildozer-1.4.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 KB 8.1 MB/s eta 0:00:00
# Collecting virtualenv
#   Downloading virtualenv-20.17.1-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 83.8 MB/s eta 0:00:00
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from buildozer) (4.8.0)
# Collecting sh
#   Downloading sh-1.14.3.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.9/62.9 KB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->buildozer) (0.7.0)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv->buildozer) (2.6.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock<4,>=3.4.1 in /usr/local/lib/python3.8/dist-packages (from virtualenv->buildozer) (3.8.2)
# Building wheels for collected packages: sh
#   Building wheel for sh (setup.py) ... done
#   Created wheel for sh: filename=sh-1.14.3-py2.py3-none-any.whl size=39654 sha256=90db46645ae533b10e45a95c844826ffe1397cb6af02c6f823ba38aab3b192ba
#   Stored in directory: /root/.cache/pip/wheels/3f/72/e2/2477a76f9fbf01a61b1dd9b34ff883288d6266d856461ba4d4
# Successfully built sh
# Installing collected packages: sh, distlib, virtualenv, buildozer
# Successfully installed buildozer-1.4.0 distlib-0.3.6 sh-1.14.3 virtualenv-20.17.1

# %%
# !pip install cython==0.29.19
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cython==0.29.19
#   Downloading Cython-0.29.19-cp38-cp38-manylinux1_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 37.1 MB/s eta 0:00:00
# Installing collected packages: cython
#   Attempting uninstall: cython
#     Found existing installation: Cython 0.29.32
#     Uninstalling Cython-0.29.32:
#       Successfully uninstalled Cython-0.29.32
# Successfully installed cython-0.29.19

# %%
# !sudo apt-get install -y \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# git is already the newest version (1:2.17.1-1ubuntu0.13).
# python3 is already the newest version (3.6.7-1~18.04).
# python3 set to manually installed.
# python3-dev is already the newest version (3.6.7-1~18.04).
# python3-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2.2).
# zlib1g-dev set to manually installed.
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# libavcodec-dev is already the newest version (7:3.4.11-0ubuntu0.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:3.4.11-0ubuntu0.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:3.4.11-0ubuntu0.1).
# libswscale-dev set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   fluidr3mono-gm-soundfont gir1.2-ibus-1.0 libcapnp-0.6.1 libdbus-1-dev
#   libfluidsynth1 libibus-1.0-5 libibus-1.0-dev libmad0 libmirclient-dev
#   libmirclient9 libmircommon-dev libmircommon7 libmircookie-dev libmircookie2
#   libmircore-dev libmircore1 libmirprotobuf3 libmodplug1 libportmidi0
#   libprotobuf-dev libprotobuf-lite10 libpulse-dev libpulse-mainloop-glib0
#   libsdl2-image-2.0-0 libsdl2-mixer-2.0-0 libsdl2-ttf-2.0-0 libsndio-dev
#   libudev-dev libxcursor-dev libxi-dev libxinerama-dev libxkbcommon-dev
#   libxrandr-dev libxv-dev python-pip-whl python3-asn1crypto
#   python3-cffi-backend python3-crypto python3-cryptography python3-idna
#   python3-keyring python3-keyrings.alt python3-pkg-resources
#   python3-secretstorage python3-setuptools python3-six python3-wheel
#   python3-xdg x11proto-input-dev x11proto-randr-dev x11proto-xinerama-dev
# Suggested packages:
#   python-crypto-doc python-cryptography-doc python3-cryptography-vectors
#   gnome-keyring libkf5wallet-bin gir1.2-gnomekeyring-1.0
#   python-secretstorage-doc python-setuptools-doc
# The following NEW packages will be installed:
#   fluidr3mono-gm-soundfont gir1.2-ibus-1.0 libcapnp-0.6.1 libdbus-1-dev
#   libfluidsynth1 libibus-1.0-5 libibus-1.0-dev libmad0 libmirclient-dev
#   libmirclient9 libmircommon-dev libmircommon7 libmircookie-dev libmircookie2
#   libmircore-dev libmircore1 libmirprotobuf3 libmodplug1 libportmidi-dev
#   libportmidi0 libprotobuf-dev libprotobuf-lite10 libpulse-dev
#   libpulse-mainloop-glib0 libsdl2-dev libsdl2-image-2.0-0 libsdl2-image-dev
#   libsdl2-mixer-2.0-0 libsdl2-mixer-dev libsdl2-ttf-2.0-0 libsdl2-ttf-dev
#   libsndio-dev libudev-dev libxcursor-dev libxi-dev libxinerama-dev
#   libxkbcommon-dev libxrandr-dev libxv-dev python-pip-whl python3-asn1crypto
#   python3-cffi-backend python3-crypto python3-cryptography python3-idna
#   python3-keyring python3-keyrings.alt python3-pip python3-pkg-resources
#   python3-secretstorage python3-setuptools python3-six python3-wheel
#   python3-xdg x11proto-input-dev x11proto-randr-dev x11proto-xinerama-dev
# 0 upgraded, 57 newly installed, 0 to remove and 21 not upgraded.
# Need to get 26.3 MB of archives.
# After this operation, 60.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fluidr3mono-gm-soundfont all 2.315-4 [18.7 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-5 amd64 1.5.17-3ubuntu5.3 [133 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-ibus-1.0 amd64 1.5.17-3ubuntu5.3 [66.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1.4 [165 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth1 amd64 1.1.9-1 [137 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-dev amd64 1.5.17-3ubuntu5.3 [145 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmad0 amd64 0.15.1b-9ubuntu18.04.1 [64.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore1 amd64 0.31.1-0ubuntu1 [26.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon7 amd64 0.31.1-0ubuntu1 [73.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirprotobuf3 amd64 0.31.1-0ubuntu1 [127 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient9 amd64 0.31.1-0ubuntu1 [199 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore-dev amd64 0.31.1-0ubuntu1 [21.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon-dev amd64 0.8.2-1~ubuntu18.04.1 [150 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon-dev amd64 0.31.1-0ubuntu1 [13.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie2 amd64 0.31.1-0ubuntu1 [19.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie-dev amd64 0.31.1-0ubuntu1 [4,392 B]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient-dev amd64 0.31.1-0ubuntu1 [47.8 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmodplug1 amd64 1:0.8.9.0-1 [150 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportmidi0 amd64 1:217-6 [17.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportmidi-dev amd64 1:217-6 [52.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-mainloop-glib0 amd64 1:11.1-1ubuntu7.11 [22.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-dev amd64 1:11.1-1ubuntu7.11 [81.5 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio-dev amd64 1.1.0-3 [13.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev-dev amd64 237-3ubuntu10.56 [19.1 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-input-dev all 2018.4-4 [2,620 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxi-dev amd64 2:1.7.9-1 [186 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-dev amd64 2.0.8+dfsg1-1ubuntu1.18.04.4 [683 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-image-2.0-0 amd64 2.0.3+dfsg1-1 [63.0 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-image-dev amd64 2.0.3+dfsg1-1 [68.6 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-mixer-2.0-0 amd64 2.0.2+dfsg1-2 [58.4 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-mixer-dev amd64 2.0.2+dfsg1-2 [73.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-ttf-2.0-0 amd64 2.0.14+dfsg1-2 [14.8 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-ttf-dev amd64 2.0.14+dfsg1-2 [19.7 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-pip-whl all 9.0.1-2.3~ubuntu1.18.04.5 [1,653 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-asn1crypto all 0.24.0-1 [72.8 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-cffi-backend amd64 1.11.5-1 [64.6 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-crypto amd64 2.6.1-8ubuntu2 [244 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-idna all 2.6-1 [32.5 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-six all 1.11.0-2 [11.4 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-cryptography amd64 2.1.4-1ubuntu1.4 [220 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-secretstorage all 2.3.1-2 [12.1 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-keyring all 10.6.0-1 [26.7 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-keyrings.alt all 3.0-1 [16.6 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-pip all 9.0.1-2.3~ubuntu1.18.04.5 [114 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pkg-resources all 39.0.1-2 [98.8 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-setuptools all 39.0.1-2 [248 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-wheel all 0.30.0-0.2 [36.5 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-xdg all 0.25-4ubuntu1.1 [31.3 kB]
# Fetched 26.3 MB in 1s (39.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 57.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fluidr3mono-gm-soundfont.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../00-fluidr3mono-gm-soundfont_2.315-4_all.deb ...
# Unpacking fluidr3mono-gm-soundfont (2.315-4) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# Preparing to unpack .../01-libibus-1.0-5_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../02-gir1.2-ibus-1.0_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libcapnp-0.6.1:amd64.
# Preparing to unpack .../03-libcapnp-0.6.1_0.6.1-1ubuntu1_amd64.deb ...
# Unpacking libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../04-libdbus-1-dev_1.12.2-1ubuntu1.4_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.2-1ubuntu1.4) ...
# Selecting previously unselected package libfluidsynth1:amd64.
# Preparing to unpack .../05-libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../06-libibus-1.0-dev_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libmad0:amd64.
# Preparing to unpack .../07-libmad0_0.15.1b-9ubuntu18.04.1_amd64.deb ...
# Unpacking libmad0:amd64 (0.15.1b-9ubuntu18.04.1) ...
# Selecting previously unselected package libmircore1:amd64.
# Preparing to unpack .../08-libmircore1_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircommon7:amd64.
# Preparing to unpack .../09-libmircommon7_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../10-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libmirprotobuf3:amd64.
# Preparing to unpack .../11-libmirprotobuf3_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient9:amd64.
# Preparing to unpack .../12-libmirclient9_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircore-dev:amd64.
# Preparing to unpack .../13-libmircore-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../14-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../15-libxkbcommon-dev_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmircommon-dev:amd64.
# Preparing to unpack .../16-libmircommon-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie2:amd64.
# Preparing to unpack .../17-libmircookie2_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie-dev:amd64.
# Preparing to unpack .../18-libmircookie-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient-dev:amd64.
# Preparing to unpack .../19-libmirclient-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../20-libmodplug1_1%3a0.8.9.0-1_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-1) ...
# Selecting previously unselected package libportmidi0:amd64.
# Preparing to unpack .../21-libportmidi0_1%3a217-6_amd64.deb ...
# Unpacking libportmidi0:amd64 (1:217-6) ...
# Selecting previously unselected package libportmidi-dev.
# Preparing to unpack .../22-libportmidi-dev_1%3a217-6_amd64.deb ...
# Unpacking libportmidi-dev (1:217-6) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../23-libpulse-mainloop-glib0_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.11) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../24-libpulse-dev_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:11.1-1ubuntu7.11) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../25-libsndio-dev_1.1.0-3_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.1.0-3) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../26-libudev-dev_237-3ubuntu10.56_amd64.deb ...
# Unpacking libudev-dev:amd64 (237-3ubuntu10.56) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../27-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-input-dev.
# Preparing to unpack .../28-x11proto-input-dev_2018.4-4_all.deb ...
# Unpacking x11proto-input-dev (2018.4-4) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../29-libxi-dev_2%3a1.7.9-1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.7.9-1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../30-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../31-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../32-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../33-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../34-libxv-dev_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../35-libsdl2-dev_2.0.8+dfsg1-1ubuntu1.18.04.4_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Selecting previously unselected package libsdl2-image-2.0-0:amd64.
# Preparing to unpack .../36-libsdl2-image-2.0-0_2.0.3+dfsg1-1_amd64.deb ...
# Unpacking libsdl2-image-2.0-0:amd64 (2.0.3+dfsg1-1) ...
# Selecting previously unselected package libsdl2-image-dev:amd64.
# Preparing to unpack .../37-libsdl2-image-dev_2.0.3+dfsg1-1_amd64.deb ...
# Unpacking libsdl2-image-dev:amd64 (2.0.3+dfsg1-1) ...
# Selecting previously unselected package libsdl2-mixer-2.0-0:amd64.
# Preparing to unpack .../38-libsdl2-mixer-2.0-0_2.0.2+dfsg1-2_amd64.deb ...
# Unpacking libsdl2-mixer-2.0-0:amd64 (2.0.2+dfsg1-2) ...
# Selecting previously unselected package libsdl2-mixer-dev:amd64.
# Preparing to unpack .../39-libsdl2-mixer-dev_2.0.2+dfsg1-2_amd64.deb ...
# Unpacking libsdl2-mixer-dev:amd64 (2.0.2+dfsg1-2) ...
# Selecting previously unselected package libsdl2-ttf-2.0-0:amd64.
# Preparing to unpack .../40-libsdl2-ttf-2.0-0_2.0.14+dfsg1-2_amd64.deb ...
# Unpacking libsdl2-ttf-2.0-0:amd64 (2.0.14+dfsg1-2) ...
# Selecting previously unselected package libsdl2-ttf-dev:amd64.
# Preparing to unpack .../41-libsdl2-ttf-dev_2.0.14+dfsg1-2_amd64.deb ...
# Unpacking libsdl2-ttf-dev:amd64 (2.0.14+dfsg1-2) ...
# Selecting previously unselected package python-pip-whl.
# Preparing to unpack .../42-python-pip-whl_9.0.1-2.3~ubuntu1.18.04.5_all.deb ...
# Unpacking python-pip-whl (9.0.1-2.3~ubuntu1.18.04.5) ...
# Selecting previously unselected package python3-asn1crypto.
# Preparing to unpack .../43-python3-asn1crypto_0.24.0-1_all.deb ...
# Unpacking python3-asn1crypto (0.24.0-1) ...
# Selecting previously unselected package python3-cffi-backend.
# Preparing to unpack .../44-python3-cffi-backend_1.11.5-1_amd64.deb ...
# Unpacking python3-cffi-backend (1.11.5-1) ...
# Selecting previously unselected package python3-crypto.
# Preparing to unpack .../45-python3-crypto_2.6.1-8ubuntu2_amd64.deb ...
# Unpacking python3-crypto (2.6.1-8ubuntu2) ...
# Selecting previously unselected package python3-idna.
# Preparing to unpack .../46-python3-idna_2.6-1_all.deb ...
# Unpacking python3-idna (2.6-1) ...
# Selecting previously unselected package python3-six.
# Preparing to unpack .../47-python3-six_1.11.0-2_all.deb ...
# Unpacking python3-six (1.11.0-2) ...
# Selecting previously unselected package python3-cryptography.
# Preparing to unpack .../48-python3-cryptography_2.1.4-1ubuntu1.4_amd64.deb ...
# Unpacking python3-cryptography (2.1.4-1ubuntu1.4) ...
# Selecting previously unselected package python3-secretstorage.
# Preparing to unpack .../49-python3-secretstorage_2.3.1-2_all.deb ...
# Unpacking python3-secretstorage (2.3.1-2) ...
# Selecting previously unselected package python3-keyring.
# Preparing to unpack .../50-python3-keyring_10.6.0-1_all.deb ...
# Unpacking python3-keyring (10.6.0-1) ...
# Selecting previously unselected package python3-keyrings.alt.
# Preparing to unpack .../51-python3-keyrings.alt_3.0-1_all.deb ...
# Unpacking python3-keyrings.alt (3.0-1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../52-python3-pip_9.0.1-2.3~ubuntu1.18.04.5_all.deb ...
# Unpacking python3-pip (9.0.1-2.3~ubuntu1.18.04.5) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../53-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../54-python3-setuptools_39.0.1-2_all.deb ...
# Unpacking python3-setuptools (39.0.1-2) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../55-python3-wheel_0.30.0-0.2_all.deb ...
# Unpacking python3-wheel (0.30.0-0.2) ...
# Selecting previously unselected package python3-xdg.
# Preparing to unpack .../56-python3-xdg_0.25-4ubuntu1.1_all.deb ...
# Unpacking python3-xdg (0.25-4ubuntu1.1) ...
# Setting up python-pip-whl (9.0.1-2.3~ubuntu1.18.04.5) ...
# Setting up libdbus-1-dev:amd64 (1.12.2-1ubuntu1.4) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up fluidr3mono-gm-soundfont (2.315-4) ...
# Setting up libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.11) ...
# Setting up libpulse-dev:amd64 (1:11.1-1ubuntu7.11) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-1) ...
# Setting up libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up python3-cffi-backend (1.11.5-1) ...
# Setting up python3-crypto (2.6.1-8ubuntu2) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up libsndio-dev:amd64 (1.1.0-3) ...
# Setting up python3-idna (2.6-1) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up python3-xdg (0.25-4ubuntu1.1) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up python3-six (1.11.0-2) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up python3-wheel (0.30.0-0.2) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up python3-pkg-resources (39.0.1-2) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up python3-asn1crypto (0.24.0-1) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up libportmidi0:amd64 (1:217-6) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up python3-pip (9.0.1-2.3~ubuntu1.18.04.5) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Setting up libsdl2-image-2.0-0:amd64 (2.0.3+dfsg1-1) ...
# Setting up libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libsdl2-ttf-2.0-0:amd64 (2.0.14+dfsg1-2) ...
# Setting up libmad0:amd64 (0.15.1b-9ubuntu18.04.1) ...
# Setting up python3-setuptools (39.0.1-2) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libudev-dev:amd64 (237-3ubuntu10.56) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up x11proto-input-dev (2018.4-4) ...
# Setting up python3-cryptography (2.1.4-1ubuntu1.4) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up python3-keyrings.alt (3.0-1) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up libsdl2-mixer-2.0-0:amd64 (2.0.2+dfsg1-2) ...
# Setting up libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libportmidi-dev (1:217-6) ...
# Setting up libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Setting up libxi-dev:amd64 (2:1.7.9-1) ...
# Setting up python3-secretstorage (2.3.1-2) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up python3-keyring (10.6.0-1) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Setting up libsdl2-ttf-dev:amd64 (2.0.14+dfsg1-2) ...
# Setting up libsdl2-image-dev:amd64 (2.0.3+dfsg1-1) ...
# Setting up libsdl2-mixer-dev:amd64 (2.0.2+dfsg1-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...

# %%
# !sudo apt-get install -y \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libgstreamer1.0-dev' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0-dbg' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0' for regex 'libgstreamer1.0'
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-gstreamer-1.0
#   gstreamer1.0-x intltool-debian libaa1 libarchive-cpio-perl
#   libarchive-zip-perl libcap2-bin libcdparanoia0 libdv4
#   libfile-stripnondeterminism-perl libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libmagic-mgc libmagic1 libmail-sendmail-perl
#   liborc-0.4-0 libpam-cap libshout3 libsigsegv2 libsys-hostname-long-perl
#   libtag1v5 libtag1v5-vanilla libtimedate-perl libtool libv4l-0 libv4lconvert0
#   libvisual-0.4-0 m4 po-debconf
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc dh-make dwz gettext-doc
#   libasprintf-dev libgettextpo-dev gvfs libdv-bin oss-compat
#   libvisual-0.4-plugins gstreamer1.0-tools gstreamer1.0-doc libtool-doc
#   gcj-jdk m4-doc libmail-box-perl
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-gstreamer-1.0
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good gstreamer1.0-x
#   intltool-debian libaa1 libarchive-cpio-perl libarchive-zip-perl libcap2-bin
#   libcdparanoia0 libdv4 libfile-stripnondeterminism-perl
#   libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgstreamer1.0-0 libgstreamer1.0-0-dbg libgstreamer1.0-dev libmagic-mgc
#   libmagic1 libmail-sendmail-perl liborc-0.4-0 libpam-cap libshout3
#   libsigsegv2 libsys-hostname-long-perl libtag1v5 libtag1v5-vanilla
#   libtimedate-perl libtool libv4l-0 libv4lconvert0 libvisual-0.4-0 m4
#   po-debconf
# 0 upgraded, 44 newly installed, 0 to remove and 21 not upgraded.
# Need to get 12.8 MB of archives.
# After this operation, 50.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcap2-bin amd64 1:2.25-1.2 [20.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpam-cap amd64 1:2.25-1.2 [7,268 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer1.0-0 amd64 1.14.5-0ubuntu1~18.04.2 [865 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-gstreamer-1.0 amd64 1.14.5-0ubuntu1~18.04.2 [71.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdparanoia0 amd64 3.10.2+debian-13 [46.7 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 liborc-0.4-0 amd64 1:0.4.28-1 [137 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.14.5-0ubuntu1~18.04.3 [689 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvisual-0.4-0 amd64 0.4.0-11 [99.2 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-plugins-base amd64 1.14.5-0ubuntu1~18.04.3 [586 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaa1 amd64 1.4p5-44build2 [47.2 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdv4 amd64 1.0.0-11 [57.8 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.14.5-0ubuntu1~18.04.3 [62.9 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libshout3 amd64 2.4.1-2build1 [43.1 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-0.2build2 [265 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-0.2build2 [10.9 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libv4lconvert0 amd64 1.14.2-1 [76.1 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libv4l-0 amd64 1.14.2-1 [41.7 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-plugins-good amd64 1.14.5-0ubuntu1~18.04.3 [1,692 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-x amd64 1.14.5-0ubuntu1~18.04.3 [74.3 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer1.0-dev amd64 1.14.5-0ubuntu1~18.04.2 [398 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer1.0-0-dbg amd64 1.14.5-0ubuntu1~18.04.2 [2,788 kB]
# Fetched 12.8 MB in 1s (9,791 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 44.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 125692 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libcap2-bin.
# Preparing to unpack .../03-libcap2-bin_1%3a2.25-1.2_amd64.deb ...
# Unpacking libcap2-bin (1:2.25-1.2) ...
# Selecting previously unselected package libpam-cap:amd64.
# Preparing to unpack .../04-libpam-cap_1%3a2.25-1.2_amd64.deb ...
# Unpacking libpam-cap:amd64 (1:2.25-1.2) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../05-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../06-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../07-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../08-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../09-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../10-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../11-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../12-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../13-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../14-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../15-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../16-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../17-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../18-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../19-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../20-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../21-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package libgstreamer1.0-0:amd64.
# Preparing to unpack .../22-libgstreamer1.0-0_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package gir1.2-gstreamer-1.0:amd64.
# Preparing to unpack .../23-gir1.2-gstreamer-1.0_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking gir1.2-gstreamer-1.0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../24-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../25-liborc-0.4-0_1%3a0.4.28-1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../26-libgstreamer-plugins-base1.0-0_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../27-libvisual-0.4-0_0.4.0-11_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-11) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../28-gstreamer1.0-plugins-base_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../29-libaa1_1.4p5-44build2_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-44build2) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../30-libdv4_1.0.0-11_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-11) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../31-libgstreamer-plugins-good1.0-0_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../32-libshout3_2.4.1-2build1_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.1-2build1) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../33-libtag1v5-vanilla_1.11.1+dfsg.1-0.2build2_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.2build2) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../34-libtag1v5_1.11.1+dfsg.1-0.2build2_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-0.2build2) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../35-libv4lconvert0_1.14.2-1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.14.2-1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../36-libv4l-0_1.14.2-1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.14.2-1) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../37-gstreamer1.0-plugins-good_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package gstreamer1.0-x:amd64.
# Preparing to unpack .../38-gstreamer1.0-x_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking gstreamer1.0-x:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../39-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libgstreamer1.0-dev:amd64.
# Preparing to unpack .../40-libgstreamer1.0-dev_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Adding 'diversion of /usr/bin/dh_gstscancodecs to /usr/bin/dh_gstscancodecs-gst0.10 by libgstreamer1.0-dev'
# Adding 'diversion of /usr/share/man/man1/dh_gstscancodecs.1.gz to /usr/share/man/man1/dh_gstscancodecs.1.gz-gst0.10 by libgstreamer1.0-dev'
# Unpacking libgstreamer1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../41-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../42-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libgstreamer1.0-0-dbg:amd64.
# Preparing to unpack .../43-libgstreamer1.0-0-dbg_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking libgstreamer1.0-0-dbg:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up libpam-cap:amd64 (1:2.25-1.2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up libcap2-bin (1:2.25-1.2) ...
# Setting up libv4lconvert0:amd64 (1.14.2-1) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up libaa1:amd64 (1.4p5-44build2) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-11) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Setting up libshout3:amd64 (2.4.1-2build1) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libdv4:amd64 (1.0.0-11) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.2build2) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-0.2build2) ...
# Setting up libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libv4l-0:amd64 (1.14.2-1) ...
# Setting up libgstreamer1.0-0-dbg:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up gir1.2-gstreamer-1.0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up libtool (2.4.6-2) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up po-debconf (1.0.20) ...
# Setting up gstreamer1.0-x:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up libgstreamer1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-autoreconf (17) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# libffi6 is already the newest version (3.2.1-8).
# libreadline-dev is already the newest version (7.0-3).
# libreadline-dev set to manually installed.
# bzip2 is already the newest version (1.0.6-8.1ubuntu0.2).
# libbz2-dev is already the newest version (1.0.6-8.1ubuntu0.2).
# libbz2-dev set to manually installed.
# liblzma-dev is already the newest version (5.2.2-1.3ubuntu0.1).
# liblzma-dev set to manually installed.
# libsqlite3-dev is already the newest version (3.22.0-1ubuntu0.7).
# libsqlite3-dev set to manually installed.
# libssl-dev is already the newest version (1.1.1-1ubuntu2.1~18.04.20).
# openssl is already the newest version (1.1.1-1ubuntu2.1~18.04.20).
# openssl set to manually installed.
# uuid-dev is already the newest version (2.31.1-0.4ubuntu3.7).
# uuid-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# Suggested packages:
#   ncurses-doc sqlite3-doc
# The following NEW packages will be installed:
#   libffi-dev libgdbm-compat-dev libgdbm-dev libncursesw5-dev sqlite3
# 0 upgraded, 5 newly installed, 0 to remove and 21 not upgraded.
# Need to get 1,191 kB of archives.
# After this operation, 4,212 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm-compat-dev amd64 1.14.1-6 [3,360 B]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdbm-dev amd64 1.14.1-6 [79.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libncursesw5-dev amd64 6.1-1ubuntu1.18.04 [199 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 sqlite3 amd64 3.22.0-1ubuntu0.7 [752 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libffi-dev amd64 3.2.1-8 [156 kB]
# Fetched 1,191 kB in 0s (8,730 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 5.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libgdbm-compat-dev.
# (Reading database ... 127548 files and directories currently installed.)
# Preparing to unpack .../libgdbm-compat-dev_1.14.1-6_amd64.deb ...
# Unpacking libgdbm-compat-dev (1.14.1-6) ...
# Selecting previously unselected package libgdbm-dev:amd64.
# Preparing to unpack .../libgdbm-dev_1.14.1-6_amd64.deb ...
# Unpacking libgdbm-dev:amd64 (1.14.1-6) ...
# Selecting previously unselected package libncursesw5-dev:amd64.
# Preparing to unpack .../libncursesw5-dev_6.1-1ubuntu1.18.04_amd64.deb ...
# Unpacking libncursesw5-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Selecting previously unselected package sqlite3.
# Preparing to unpack .../sqlite3_3.22.0-1ubuntu0.7_amd64.deb ...
# Unpacking sqlite3 (3.22.0-1ubuntu0.7) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../libffi-dev_3.2.1-8_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.2.1-8) ...
# Setting up libgdbm-dev:amd64 (1.14.1-6) ...
# Setting up libffi-dev:amd64 (3.2.1-8) ...
# Setting up sqlite3 (3.22.0-1ubuntu0.7) ...
# Setting up libncursesw5-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Setting up libgdbm-compat-dev (1.14.1-6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !sudo apt-get install libffi-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libffi-dev is already the newest version (3.2.1-8).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.

# %%
# !unzip /content/Password-Generator.zip -d /content/
# Out:
# Archive:  /content/Password-Generator.zip
#    creating: /content/Password-Generator/.git/
#  extracting: /content/Password-Generator/.git/COMMIT_EDITMSG
#   inflating: /content/Password-Generator/.git/config
#   inflating: /content/Password-Generator/.git/description
#  extracting: /content/Password-Generator/.git/HEAD
#    creating: /content/Password-Generator/.git/hooks/
#   inflating: /content/Password-Generator/.git/hooks/applypatch-msg.sample
#   inflating: /content/Password-Generator/.git/hooks/commit-msg.sample
#   inflating: /content/Password-Generator/.git/hooks/fsmonitor-watchman.sample
#   inflating: /content/Password-Generator/.git/hooks/post-update.sample
#   inflating: /content/Password-Generator/.git/hooks/pre-applypatch.sample
#   inflating: /content/Password-Generator/.git/hooks/pre-commit.sample
#   inflating: /content/Password-Generator/.git/hooks/pre-merge-commit.sample
#   inflating: /content/Password-Generator/.git/hooks/prepare-commit-msg.sample
#   inflating: /content/Password-Generator/.git/hooks/pre-push.sample
#   inflating: /content/Password-Generator/.git/hooks/pre-rebase.sample
#   inflating: /content/Password-Generator/.git/hooks/pre-receive.sample
#   inflating: /content/Password-Generator/.git/hooks/push-to-checkout.sample
#   inflating: /content/Password-Generator/.git/hooks/update.sample
#   inflating: /content/Password-Generator/.git/index
#    creating: /content/Password-Generator/.git/info/
#   inflating: /content/Password-Generator/.git/info/exclude
#    creating: /content/Password-Generator/.git/logs/
#   inflating: /content/Password-Generator/.git/logs/HEAD
#    creating: /content/Password-Generator/.git/logs/refs/
#    creating: /content/Password-Generator/.git/logs/refs/heads/
#   inflating: /content/Password-Generator/.git/logs/refs/heads/main
#    creating: /content/Password-Generator/.git/logs/refs/remotes/
#    creating: /content/Password-Generator/.git/logs/refs/remotes/origin/
#   inflating: /content/Password-Generator/.git/logs/refs/remotes/origin/HEAD
#   inflating: /content/Password-Generator/.git/logs/refs/remotes/origin/main
#    creating: /content/Password-Generator/.git/objects/
#    creating: /content/Password-Generator/.git/objects/1a/
#  extracting: /content/Password-Generator/.git/objects/1a/5866e485cd07cfa7a2b5f73595faee24e15731
#    creating: /content/Password-Generator/.git/objects/2c/
#  extracting: /content/Password-Generator/.git/objects/2c/01b63f96e57cc6ac1107a99c71f25ef1f07c73
#    creating: /content/Password-Generator/.git/objects/53/
#  extracting: /content/Password-Generator/.git/objects/53/6f991b0615e1ecf41e3a9bee972bebf0f80988
#    creating: /content/Password-Generator/.git/objects/5e/
#  extracting: /content/Password-Generator/.git/objects/5e/0ddfd3a6dafc6a913393a54d133f5068f09184
#    creating: /content/Password-Generator/.git/objects/80/
#  extracting: /content/Password-Generator/.git/objects/80/2fd059dcdded0bc0c512845168706fb24668e3
#  extracting: /content/Password-Generator/.git/objects/80/5b651da664b8514cfdf612048552b12c479502
#    creating: /content/Password-Generator/.git/objects/8c/
#  extracting: /content/Password-Generator/.git/objects/8c/7d853edca625033ddc28a871908166ef3d858a
#    creating: /content/Password-Generator/.git/objects/be/
#  extracting: /content/Password-Generator/.git/objects/be/1cacb3019e07e2b3be6d2a641d3a0d2d49973f
#    creating: /content/Password-Generator/.git/objects/c8/
#   inflating: /content/Password-Generator/.git/objects/c8/4395ed09c4db314fd3ebe26b5f97dcb9e8a3ce
#    creating: /content/Password-Generator/.git/objects/e6/
#  extracting: /content/Password-Generator/.git/objects/e6/9de29bb2d1d6434b8b29ae775ad8c2e48c5391
#    creating: /content/Password-Generator/.git/objects/f8/
#  extracting: /content/Password-Generator/.git/objects/f8/83b9dfc42053dd8ce408631d0cbdef1ddcaf0c
#   inflating: /content/Password-Generator/.git/objects/f8/a86acbd1fd04521268a1a43234a0d6df238d32
#    creating: /content/Password-Generator/.git/objects/info/
#    creating: /content/Password-Generator/.git/objects/pack/
#   inflating: /content/Password-Generator/.git/objects/pack/pack-ad3004e9be10f7a3c141140bf73913b6415db000.idx
#  extracting: /content/Password-Generator/.git/objects/pack/pack-ad3004e9be10f7a3c141140bf73913b6415db000.pack
#   inflating: /content/Password-Generator/.git/packed-refs
#    creating: /content/Password-Generator/.git/refs/
#    creating: /content/Password-Generator/.git/refs/heads/
#  extracting: /content/Password-Generator/.git/refs/heads/main
#    creating: /content/Password-Generator/.git/refs/remotes/
#    creating: /content/Password-Generator/.git/refs/remotes/origin/
#  extracting: /content/Password-Generator/.git/refs/remotes/origin/HEAD
#  extracting: /content/Password-Generator/.git/refs/remotes/origin/main
#    creating: /content/Password-Generator/.git/refs/tags/
#   inflating: /content/Password-Generator/.gitignore
#    creating: /content/Password-Generator/__pycache__/
#   inflating: /content/Password-Generator/__pycache__/password_generator.cpython-38.pyc
#    creating: /content/Password-Generator/artifacts/
#   inflating: /content/Password-Generator/artifacts/list_titles.pkl
#   inflating: /content/Password-Generator/artifacts/Top_10000_Movies_2.csv
#   inflating: /content/Password-Generator/LICENSE
#   inflating: /content/Password-Generator/main.py
#   inflating: /content/Password-Generator/password_generator.py
#   inflating: /content/Password-Generator/README.md
#   inflating: /content/Password-Generator/requirements.txt
#    creating: /content/Password-Generator/test/
#  extracting: /content/Password-Generator/test/__init__.py
#   inflating: /content/Password-Generator/test/test_app.ipynb
#   inflating: /content/Password-Generator/test/test_password_generator.ipynb

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/Password-Generator
# !ls
# Out:
# /content/Password-Generator
# artifacts	LICENSE  password_generator.py	README.md	  test
# buildozer.spec	main.py  __pycache__		requirements.txt

# %%
# !buildozer init
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# File buildozer.spec created, ready to customize!

# %%
# !buildozer -v android debug
# Out:
# Streaming output truncated to the last 5000 lines.
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/numeric.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/numerictypes.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/overrides.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/records.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/setup.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/setup_common.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/shape_base.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/_locales.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/data'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/examples'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/examples/cython'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/examples/cython/setup.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/examples/limited_api'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/examples/limited_api/setup.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test__exceptions.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_abc.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_api.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_argparse.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_array_coercion.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_arraymethod.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_arrayprint.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_casting_unittests.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_conversion_utils.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_cpu_dispatcher.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_cpu_features.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_custom_dtypes.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_cython.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_datetime.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_defchararray.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_deprecations.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_dlpack.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_dtype.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_einsum.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_errstate.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_extint128.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_function_base.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_getlimits.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_half.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_hashtable.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_indexerrors.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_indexing.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_item_selection.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_limited_api.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_longdouble.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_machar.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_mem_overlap.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_mem_policy.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_memmap.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_multiarray.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_nditer.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_numeric.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_numerictypes.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_overrides.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_print.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_protocols.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_records.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_regression.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_scalar_ctors.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_scalar_methods.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_scalarbuffer.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_scalarinherit.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_scalarmath.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_scalarprint.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_shape_base.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_simd.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_simd_module.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_ufunc.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_umath.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_umath_accuracy.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_umath_complex.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/tests/test_unicode.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/umath.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/core/umath_tests.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/ctypeslib.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/__config__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/_shell_utils.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/armccompiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/ccompiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/ccompiler_opt.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/checks'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/autodist.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/bdist_rpm.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/build.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/build_clib.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/build_ext.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/build_py.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/build_scripts.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/build_src.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/config.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/config_compiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/develop.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/egg_info.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/install.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/install_clib.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/install_data.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/install_headers.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/command/sdist.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/conv_template.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/core.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/cpuinfo.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/exec_command.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/extension.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/absoft.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/arm.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/compaq.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/environment.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/fujitsu.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/g95.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/gnu.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/hpux.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/ibm.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/intel.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/lahey.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/mips.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/nag.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/none.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/nv.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/pathf95.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/pg.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/sun.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/fcompiler/vast.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/from_template.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/intelccompiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/lib2def.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/line_endings.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/log.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/mingw'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/mingw32ccompiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/misc_util.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/msvc9compiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/msvccompiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/npy_pkg_config.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/numpy_distribution.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/pathccompiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/setup.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/system_info.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_build_ext.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_ccompiler_opt.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_ccompiler_opt_conf.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_exec_command.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_fcompiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_fcompiler_gnu.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_fcompiler_intel.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_fcompiler_nagfor.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_from_template.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_log.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_mingw32ccompiler.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_misc_util.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_npy_pkg_config.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_shell_utils.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/tests/test_system_info.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/distutils/unixccompiler.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/doc'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/doc/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/doc/constants.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/doc/ufuncs.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/dual.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/__main__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/__version__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/auxfuncs.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/capi_maps.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/cb_rules.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/cfuncs.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/common_rules.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/crackfortran.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/diagnose.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/f2py2e.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/f2py_testing.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/f90mod_rules.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/func2subr.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/rules.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/setup.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/src'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/symbolic.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/__init__.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/array_from_pyobj'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/assumed_shape'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/common'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/kind'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/mixed'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/module_data'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/parameter'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/regression'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/size'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/src/string'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_abstract_interface.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_array_from_pyobj.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_assumed_shape.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_block_docstring.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_callback.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_common.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_compile_function.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_crackfortran.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_kind.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_mixed.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_module_doc.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_parameter.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_quoted_character.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_regression.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_return_character.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_return_complex.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_return_integer.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_return_logical.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_return_real.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_semicolon_split.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_size.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_string.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/test_symbolic.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/tests/util.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/f2py/use_rules.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/fft'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/fft/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/fft/_pocketfft.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/fft/helper.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/fft/setup.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/fft/tests'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/fft/tests/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/fft/tests/test_helper.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/fft/tests/test_pocketfft.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/__init__.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/_datasource.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/_iotools.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/_version.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/arraypad.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/arraysetops.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/arrayterator.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/format.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/function_base.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/histograms.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/index_tricks.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/mixins.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/nanfunctions.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/npyio.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/polynomial.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/recfunctions.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/scimath.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/setup.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/shape_base.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/stride_tricks.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/__init__.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/data'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test__datasource.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test__iotools.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test__version.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_arraypad.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_arraysetops.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_arrayterator.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_financial_expired.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_format.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_function_base.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_histograms.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_index_tricks.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_io.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_mixins.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_nanfunctions.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_packbits.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_polynomial.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_recfunctions.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_regression.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_shape_base.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_stride_tricks.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_twodim_base.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_type_check.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_ufunclike.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/tests/test_utils.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/twodim_base.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/type_check.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/ufunclike.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/user_array.py'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/lib/utils.py'...
# Listing '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/linalg'...
# Compiling '/content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/EPG/arm64-v8a/numpy/linalg/__init__.py'...
# ...
# Compiling '/content/Password-Generator/.buildozer/android/app/sitecustomize.py'...
# Compiling '/content/Password-Generator/.buildozer/android/app/password_generator.py'...
# Compiling '/content/Password-Generator/.buildozer/android/app/main.py'...
# Compiling '/content/Password-Generator/.buildozer/android/app/test/__init__.py'...
# [INFO]:    Detected highest available build tools version to be 33.0.1
# [DEBUG]:   -> running gradlew clean assembleDebug
# [DEBUG]:   	Downloading https://services.gradle.org/distributions/gradle-7.4.1-all.zip
# [DEBUG]:   	.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................... ...
# [DEBUG]:   	Unzipping /root/.gradle/wrapper/dists/gradle-7.4.1-all/8bevta3mh7872g50ecurigeld/gradle-7.4.1-all.zip to /root/.gradle/wrapper/dists/gradle-7.4.1-all/8bevta3mh7872g50ecurigeld
# [DEBUG]:   	Set executable permissions for: /root/.gradle/wrapper/dists/gradle-7.4.1-all/8bevta3mh7872g50ecurigeld/gradle-7.4.1/bin/gradle
# [DEBUG]:
# [DEBUG]:   	Welcome to Gradle 7.4.1!
# [DEBUG]:
# [DEBUG]:   	Here are the highlights of this release:
# [DEBUG]:   	 - Aggregated test and JaCoCo reports
# [DEBUG]:   	 - Marking additional test source directories as tests in IntelliJ
# [DEBUG]:   	 - Support for Adoptium JDKs in Java toolchains
# [DEBUG]:
# [DEBUG]:   	For more details see https://docs.gradle.org/7.4.1/release-notes.html
# [DEBUG]:
# [DEBUG]:   	Starting a Gradle Daemon (subsequent builds will be faster)
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	> Starting Daemon> Starting Daemon > Connecting to Daemon> IDLE<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING s]<-------------> 0% INITIALIZING [1s]> Evaluating settings<-------------> 0% INITIALIZING [2s]<-------------> 0% INITIALIZING [3s]<-------------> 0% CONFIGURING [3s]> Loading projects> root project> root project > Compiling build file 'build.gradle'<-------------> 0% CONFIGURING [4s]<-------------> 0% CONFIGURING [5s]> root project<-------------> 0% CONFIGURING [6s]> root project > Resolve dependencies of :classpath> root project > Resolve dependencies of :classpath > gradle-7.1.2.pom<-------------> 0% CONFIGURING [7s]> root project > Resolve dependencies of :classpath> root project > Resolve dependencies of :classpath > sdklib-30.1.2.pom
# [DEBUG]:   	> root project > Resolve dependencies of :classpath > httpmime-4.5.6.pom> root project > Resolve dependencies of :classpath > sdklib-30.1.2.module<-------------> 0% CONFIGURING [8s]> root project > Resolve dependencies of :classpath > httpmime-4.5.6.pom > 3.3 > root project > Resolve dependencies of :classpath > commons-io-2.4.pom> root project > Resolve dependencies of :classpath > commons-parent-25.pom> IDLE> root project > Resolve dependencies of :classpath> root project > Resolve dependencies of :classpath > apache-9.pom> root project > Resolve dependencies of :classpath > asm-9.1.pom> root project > Resolve dependencies of :classpath > ow2-1.5.pom> root project > Resolve dependencies of :classpath > asm-commons-9.1.pom> root project > Resolve dependencies of :classpath > asm-util-9.1.pom> IDLE> root project > Resolve dependencies of :classpath > jaxb-runtime-2.3.2.pom> root project > Resolve dependencies of :classpath > jaxb-parent-2.3.2.pom> root project > Resolve dependencies of :classpath > jopt-simple-4.9.pom> root project > Resolve dependencies of :classpath > jaxb-bom-ext-2.3.2.pom> IDLE<-------------> 0% CONFIGURING [9s]> root project > Resolve dependencies of :classpath > project-1.0.5.pom> root project > Resolve dependencies of :classpath > jetifier-processor-1.0.0-> root project > Resolve dependencies of :classpath > protobuf-java-3.10.0.pom> root project > Resolve dependencies of :classpath > protobuf-java-util-3.10.0> IDLE> root project > Resolve dependencies of :classpath > protobuf-parent-3.10.0.po> root project > Resolve dependencies of :classpath > protobuf-bom-3.10.0.pom> root project > Resolve dependencies of :classpath > gson-parent-2.8.6.pom > 2> root project > Resolve dependencies of :classpath > grpc-core-1.21.1.pom> root project > Resolve dependencies of :classpath > grpc-protobuf-1.21.1.pom> root project > Resolve dependencies of :classpath > grpc-netty-1.21.1.pom> root project > Resolve dependencies of :classpath > core-proto-0.0.8-alpha07.> root project > Resolve dependencies of :classpath > dokka-core-1.4.32.pom> root project > Resolve dependencies of :classpath > tensorflow-lite-metadata-> root project > Resolve dependencies of :classpath > builder-7.1.2.pom> IDLE> root project > Resolve dependencies of :classpath > builder-7.1.2.module<-------------> 0% CONFIGURING [10s]> root project > Resolve dependencies of :classpath > repository-30.1.2.pom> root project > Resolve dependencies of :classpath > gradle-api-7.1.2.pom> root project > Resolve dependencies of :classpath > android-test-plugin-host-> root project > Resolve dependencies of :classpath > ddmlib-30.1.2.pom> root project > Resolve dependencies of :classpath > aapt2-proto-7.1.2-7984345> root project > Resolve dependencies of :classpath > kotlin-stdlib-jdk8-1.4.32> IDLE> root project > Resolve dependencies of :classpath > android-test-plugin-resul> root project > Resolve dependencies of :classpath > aaptcompiler-7.1.2.pom> root project > Resolve dependencies of :classpath > crash-30.1.2.pom> root project > Resolve dependencies of :classpath > android-test-plugin-host-> root project > Resolve dependencies of :classpath > crash-30.1.2.module> IDLE> root project > Resolve dependencies of :classpath > shared-30.1.2.module> root project > Resolve dependencies of :classpath > android-device-provider-g> root project > Resolve dependencies of :classpath > lint-model-30.1.2.module> root project > Resolve dependencies of :classpath > android-device-provider-d> root project > Resolve dependencies of :classpath > databinding-compiler-comm<-------------> 0% CONFIGURING [11s]> root project > Resolve dependencies of :classpath > databinding-common-7.1.2.> root project > Resolve dependencies of :classpath > layoutlib-api-30.1.2.pom> root project > Resolve dependencies of :classpath > builder-test-api-7.1.2.po> root project > Resolve dependencies of :classpath > baseLibrary-7.1.2.module> root project > Resolve dependencies of :classpath > buil ...
# [DEBUG]:   	> Configure project :
# [DEBUG]:   	WARNING:Using flatDir should be avoided because it doesn't support any meta-data formats.
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<-------------> 0% CONFIGURING [42s]> root project> IDLE<-------------> 0% CONFIGURING [43s]<=============> 100% CONFIGURING [43s]> IDLE<=============> 100% CONFIGURING [44s]<=============> 100% CONFIGURING [45s]<-------------> 0% EXECUTING [45s]<-------------> 7% EXECUTING [45s]> :mergeDebugNativeDebugMetadata<=------------> 15% EXECUTING [45s]> :generateDebugBuildConfig<==-----------> 17% EXECUTING [45s]> :javaPreCompileDebug<===----------> 27% EXECUTING [45s]> :mergeDebugResources> :createDebugCompatibleScreenManifests<====---------> 32% EXECUTING [46s]> :processDebugMainManifest<====---------> 35% EXECUTING [46s]> :processDebugManifest<====---------> 37% EXECUTING [46s]> IDLE<======-------> 47% EXECUTING [46s]> :mergeDebugAssets> :processDebugManifestForPackage<======-------> 52% EXECUTING [47s]> IDLE> :processDebugResources> :processDebugResources > Resolve dependencies of :detachedConfiguration1 > aa> :processDebugResources > Resolve files of :detachedConfiguration1 > aapt2-7.1> :processDebugResources > Resolve files of :detachedConfiguration1> :processDebugResources > Resolve files of :detachedConfiguration1 > Aapt2Extr> :processDebugResources > Resolve files of :detachedConfiguration1> :compressDebugAssets> :processDebugResources<=======------> 57% EXECUTING [48s]> IDLE> :compileDebugJavaWithJavac<=======------> 57% EXECUTING [49s]<=======------> 57% EXECUTING [50s]<=======------> 57% EXECUTING [51s]
# [DEBUG]:   	> Task :compileDebugJavaWithJavac
# [DEBUG]:   	Note: Some input files use or override a deprecated API.
# [DEBUG]:   	Note: Recompile with -Xlint:deprecation for details.
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<=======------> 57% EXECUTING [52s]> IDLE> :compileDebugJavaWithJavac<========-----> 62% EXECUTING [52s]> :checkDebugDuplicateClasses> :mergeDebugJavaResource<========-----> 67% EXECUTING [52s]> :mergeLibDexDebug<=========----> 72% EXECUTING [52s]> :dexBuilderDebug> IDLE<=========----> 72% EXECUTING [53s]<=========----> 72% EXECUTING [54s]<=========----> 72% EXECUTING [55s]<=========----> 72% EXECUTING [56s]<=========----> 72% EXECUTING [57s]<=========----> 75% EXECUTING [57s]> :mergeProjectDexDebug> :mergeDebugJniLibFolders<==========---> 77% EXECUTING [57s]> IDLE<==========---> 77% EXECUTING [58s]<==========---> 80% EXECUTING [58s]> :validateSigningDebug> :mergeDebugNativeLibs<==========---> 80% EXECUTING [59s]<==========---> 82% EXECUTING [59s]> IDLE<==========---> 82% EXECUTING [1m]<===========--> 85% EXECUTING [1m]> :stripDebugDebugSymbols
# [DEBUG]:   	> Task :stripDebugDebugSymbols
# [DEBUG]:   	Unable to strip the following libraries, packaging them as they are: libSDL2.so, libSDL2_image.so, libSDL2_mixer.so, libSDL2_ttf.so, libbz2.so, libc++_shared.so, libcrypto1.1.so, libffi.so, liblzma.so, libmain.so, libpybundle.so, libpython3.9.so, libsqlite3.so, libssl1.1.so.
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<============-> 92% EXECUTING [1m]> :packageDebug> IDLE<============-> 92% EXECUTING  1s]<============-> 92% EXECUTING  2s]<============-> 92% EXECUTING  3s]<============-> 92% EXECUTING  4s]<============-> 92% EXECUTING  5s]<============-> 92% EXECUTING  6s]<=============> 100% EXECUTING  6s]> IDLE
# [DEBUG]:   	Deprecated Gradle features were used in this build, making it incompatible with Gradle 8.0.
# [DEBUG]:
# [DEBUG]:   	You can use '--warning-mode all' to show the individual deprecation warnings and determine if they come from your own scripts or plugins.
# [DEBUG]:
# [DEBUG]:   	See https://docs.gradle.org/7.4.1/userguide/command_line_interface.html#sec:command_line_warnings
# [DEBUG]:
# [DEBUG]:   	BUILD SUCCESSFUL in 1m 18s
# [DEBUG]:   	30 actionable tasks: 29 executed, 1 up-to-date
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<-------------> 0% WAITING> IDLE> IDLE
# [INFO]:    <- directory context /content/Password-Generator/.buildozer/android/platform/python-for-android
# [INFO]:    Of the existing distributions, the following meet the given requirements:
# [INFO]:    	EPG: min API 21, includes recipes (hostpython3, libbz2, libffi, liblzma, openssl, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, pytz, setuptools, cython, six, numpy, pyjnius, android, kivy, pandas, certifi, python-dateutil), built for archs (armeabi-v7a, arm64-v8a)
# [INFO]:    EPG has compatible recipes, using this one
# [INFO]:    # Copying android package to current directory
# [INFO]:    # Android package filename not found in build output. Guessing...
# [INFO]:    # Found android package file: /content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists/EPG/build/outputs/apk/debug/EPG-debug.apk
# [INFO]:    # Add version number to android package
# [INFO]:    # Android package renamed to EPG-debug-0.1.apk
# [DEBUG]:   -> running cp /content/Password-Generator/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists/EPG/build/outputs/apk/debug/EPG-debug.apk EPG-debug-0.1.apk
# WARNING: Received a --sdk argument, but this argument is deprecated and does nothing.
# No setup.py/pyproject.toml used, copying full private data into .apk.
# Applying Java source code patches...
# Applying patch: src/patches/SDLActivity.java.patch
# # Android packaging done!
# # APK EPG-0.1-arm64-v8a_armeabi-v7a-debug.apk available in the bin directory

# %%
y!pwd
# Out:
# /content

# %%
# !buildozer android clean
